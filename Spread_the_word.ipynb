# %% [markdown]
# <a href="https://colab.research.google.com/github/deleyva/seminario-tic-10-mayo/blob/master/Spread_the_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sesión Seminario TIC 10 de mayo 2019
#
# > Si os animáis, id instalando [anaconda](https://repo.anaconda.com/archive/Anaconda3-2019.03-Windows-x86_64.exe).
#
# Descargad los archivos de [aquí](https://github.com/deleyva/seminario-tic-10-mayo/tree/master/notebooks), y subid los archivos txt a este notebook.

# %% [markdown]
# # ¿Para qué aprender a progamar?
#
# ### Que la máquina trabaje para tí, y no al revés
#
# * Automatizar tareas aburridas.
# * Resolver un problema difícil de análisis de datos.
# * Crear webs, apps... web apps.
# * Comunicad dispositivos a través del Internet Of Things.
# * Sacarle verdadero partido a la tecnología en nuestras respectivas áreas de conocimiento.

# %% [markdown]
# "Ciertamente, la revolución agrícola amplió la suma total de alimento a disposición de la humanidad, pero el alimento adicional no se tradujo en una dieta mejor o en más ratos de ocio, sino en explosiones demográficas y élites consentidas. El agricultor medio trabajaba más duro que el cazador-recolector medio, y a cambio obtenía una dieta peor. La revolución agrícola fue el mayor fraude de la historia. ¿Quién fue el responsable? Ni reyes, ni sacerdotes, ni mercaderes. Los culpables fueron un puñado de especies de plantas, entre las que se cuentan el trigo, el arroz y las patatas. Fueron estas plantas las que domesticaron a Homo sapiens, y no al revés."
#
# _Harari, Yuval Noah. Sapiens. De animales a dioses: Una breve historia de la humanidad_

# %% [markdown]
# #### Algo que me hizo pensar
#
# [![](https://github.com/deleyva/seminario-tic-10-mayo/blob/master/notebooks/img/encuesta-stackoverflow.png?raw=1)](https://insights.stackoverflow.com/survey/2018/#developer-profile-_-how-much-time-do-developers-spend-on-a-computer)

# %% [markdown]
# _Gran parte del material a continuación ha sido extraído del artículo [Everything About Python — Beginner To Advanced](https://medium.com/fintechexplained/everything-about-python-from-beginner-to-advance-level-227d52ef32d2) de Farhad Malik_ y del curso _[Python for Everybody](https://www.py4e.com/lessons)_

# %% [markdown]
# # Introducción a Python
#
# ## ¿Qué es Python?
#
# - Lenguaje de programación **interpretado** de **alto nivel orientado a objetos**.
# - El intérprete de Python, lee una línea de código a la vez, lo interpreta en lenguaje de máquina de bajo nivel (código de bytes) y luego lo ejecuta.
# - Como resultado, generalmente se encuentran **errores de tiempo de ejecución**.

# %% [markdown]
# ## ¿Por qué Python?
#
# ![Lenguages de programación](https://github.com/deleyva/seminario-tic-10-mayo/blob/master/notebooks/img/languages.png?raw=1)
#
# - Python es el lenguaje _más popular_ **(muy popular)** debido a que es más fácil codificarlo y entenderlo.
# - Python es un lenguaje de programación **orientado a objetos** y se puede usar para escribir **código funcional también**.
# - **Lleva menos tiempo** llevar un programa Python al mercado en comparación con otros lenguajes como C# o Java.
# - Además, hay una **gran cantidad de librearías** de análisis de datos y de machine learning desarrolados en Python.
# - Una **gran cantidad de comunidades y libros**. están disponibles para apoyar a los desarrolladores de Python.
# - En Python **se pueden implementar casi todo tipo de aplicaciones**, que van desde la previsión analítica al desarrollo de web apps.

# %% [markdown]
# ## ¿Por qué no Python?
#
# - Python es más lento que C++, C#, Java.
# - La restricción sintáctica del espacio en blanco de Python hace que sea un poco difícil de implementar para los nuevos codificadores.
# - Python no es adecuado para niveles bajos -inivel del sistema y la interacción de hardware.

# %% [markdown]
# #### Mi versión de porqué no
# - Es un lenguaje de servidor. Para desarrollar la parte visual de las aplicaciones al final te viene bien saber algo de Javascript y ya que te pones, Javascript te vale tanto para servidor como para cliente. No obstante, Javascript es más complejo y le faltan muchas de las capacidades de Python.

# %% [markdown]
# # Variables
#
# - Las variables almacenan información que se puede usar en tu programa, por ejemplo, para mantener las entradas de los usuarios, los estados locales de tu programa, etc.
# - Python admite números, cadenas, conjuntos, listas, tuplas y diccionarios. Estos son los tipos de datos estándar.

# %% [markdown]
# ## Declarar y asignar valor a la variable
#
# La asignación establece un valor para una variable:

# %%
mi_primera_variable = 1
mi_segunda_variable = 2
mi_primera_variable = "Hola mundo"
print(mi_primera_variable)

# %% [markdown]
# - La asignación de un valor se conoce como **binding** en Python.
#
# **Observa cómo he asignado un valor entero de 1 y luego un valor de cadena de "Hola, usted" a la variable myFirstVariable.** Esto es posible debido al hecho de que los tipos de datos se escriben dinámicamente en python.

# %% [markdown]
# ### Numérico
# - Se admiten enteros, decimales, flotantes.

# %%
value = 1 #integer
value = 1.2 #float with a floating point

# %% [markdown]
# - También se admiten largos. Tienen un sufijo de L e.g. 9999999999999L

# %% [markdown]
# ### Comas en variables de números enteros.
# - Las comas se tratan como secuencia de variables:

# %%
a, b, c = 9,8,7
print(a)
print(b)
print(c)

# %% [markdown]
# ### Operaciones
#
# - Podemos realizar cálculos sobre variables.
#
# #### Operaciones Numéricas
# - Python es compatible con *, /, +, -

# %%
1/3

# %% [markdown]
# - Python también es compatible con la división entera:

# %%
1//3

# %% [markdown]
# Además, Python admite exponenciación a través del operador **:

# %%
2 ** 3

# %% [markdown]
# - Python también es compatible con el operador Módulo (resto):

# %%
7%2

# %% [markdown]
# ### Comprobando el tipo de una variable
#
# - Si quieres comprobar el tipo de una variable, puedes usar la función type():

# %%
type('farhad')

# %% [markdown]
# ### Palabras reservadas
#
# ```python
# and       del       from      None      True
# as        elif      global    nonlocal  try
# assert    else      if        not       while
# break     except    import    or        with
# class     False     in        pass      yield
# continue  finally   is        raise
# def       for       lambda    return
# ```

# %% [markdown]
# ### Preguntando al usuario por la entrada

# %%
name = input('¿cómo te llamas')
print(name)

# %% [markdown]
# ### Comentarios
#
# Viene muy bien explicar qué hace nuestro código, aunque sea sólo para nosotros mismos en el futuro.
#
# Por esta razón, es una buena idea agregar notas a tus programas para explicar en lenguaje natural lo que está haciendo el programa. Estas notas se llaman comentarios, y en Python comienzan con el símbolo #:
#
# ```python
# # compute the percentage of the hour that has elapsed
# percentage = (minute * 100) / 60
# ```

# %% [markdown]
# ### Casting
#
# - str(x): a cadena
# - int(x): a entero
# - float(x): a decimal

# %%
cadena = '2'
2 + cadena

# %% [markdown]
# # Condicionales
#
# Una expresión booleana es una expresión que es verdadera o falsa. Los siguientes ejemplos usan el operador ==, que compara dos operandos y produce True si son iguales y False de lo contrario:+

# %%
5 == 5

# %%
5 == 6

# %% [markdown]
# True y False son valores especiales que pertenecen a la clase bool; no son cadenas.

# %%
type(True)

# %% [markdown]
# ## Operadores
#
# El operador == es uno de los operadores de comparación; los otros son:
#
# ```python
#       x != y               # x is not equal to y
#       x > y                # x is greater than y
#       x < y                # x is less than y
#       x >= y               # x is greater than or equal to y
#       x <= y               # x is less than or equal to y
#       x is y               # x is the same as y
#       x is not y           # x is not the same as y
# ```

# %% [markdown]
# ## Operadores lógicos
#
# Hay tres operadores lógicos: and, or, y not. La semántica (significado) de estos operadores es similar a su significado en inglés. Por ejemplo,

# %%
x > 0 and x < 10

# %% [markdown]
# ## Ejecución condicional

# %%
x = 0
y = 0

if x < y:
    print('x is less than y')
elif x > y:
    print('x is greater than y')
else:
    print('x and y are equal')

# %% [markdown]
# ## Condicionales anidados

# %%
x = 0
y = 0

if x == y:
    print('x and y are equal')
else:
    if x < y:
        print('x is less than y')
    else:
        print('x is greater than y')

# %% [markdown]
# ## Capturando excepciones con `try` y `except`
#
# Si se produce un en una secuencia de comandos de Python, la secuencia de comandos se detiene inmediatamente dejando una traza de lo que se estaba ejecutando cuando el programa falló. No ejecuta la siguiente sentencia.
#
# Para evitar esto utilizamos los bloques `try` y `except`

# %%
inp = input('Enter Fahrenheit Temperature: ')

try:
    fahr = float(inp)
    cel = (fahr - 32.0) * 5.0 / 9.0
    print(cel)
except:
    print('Tipo de dato equivocado')

# %% [markdown]
# ## Ejercicios
#
# ### Ejercicio 1
#
# Escribe un programa que use input para pedirle a un usuario su nombre y luego le de la bienvenida.
#
# ```bash
# Enter your name: Chuck
# Hello Chuck
# ```

# %%
name = input('¿Cómo te llamas? ')
print('Hola' + name)
# Out:
# ¿Cómo te llamas? Jesús
# HolaJesús

# %% [markdown]
# ### Ejercicio 2
#
# Escribe un programa para pedirle al usuario las horas y la tarifa por hora para calcular el pago bruto.
#
# ```python
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```

# %%
horas = input('horas ')
rate = input('rate ')
horas = int(horas)
rate = int(rate)
print(horas * rate)
# Out:
# horas 5
# rate 90
# 450

# %% [markdown]
# ### Ejercicio 3
#
# Reescribe tu cálculo de pago para darle al empleado 1.5 veces la tarifa por hora por las horas trabajadas por encima de las 40 horas.
#
# ```
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0
# ```

# %% [markdown]
# # Funciones
#
# En el contexto de la programación, una función es una secuencia de instrucciones con nombre que realiza un cálculo. Cuando defines una función, especifica el nombre y la secuencia de instrucciones. Más tarde, puedes "llamar" a la función por su nombre. Ya hemos visto un ejemplo de una llamada a una función:
#
# ```python
# >>> type(32)
# <class 'int'>
# ```

# %% [markdown]
# ## Funciones incorporadas

# %%
print(max('Hello world'))
print(min('Hello world'))
len('Hello world')

# %% [markdown]
# ## Importando librerías
#
# * [random](https://docs.python.org/3/library/random.html)
# * [math](https://docs.python.org/3/library/math.html)

# %%
import random

random.randint(4, 10)

# %%
import math

grados = 45
radianes = grados / 360.0 * 2 * math.pi
math.sin(radianes)

# %%
math.sqrt(49)

# %% [markdown]
# ## Definiendo funciones
#
# ¿Cómo encapsular en una función el siguiente código?

# %%
import math

grados = 45
radianes = grados / 360.0 * 2 * math.pi
print(radianes)

# %% [markdown]
# ### No reinventes la rueda

# %%
grados = float(input('Introduce los grados: '))

math.radians(grados)

# %% [markdown]
# ## Parámetros
#
# Algunas de las funciones incorporadas que hemos visto requieren argumentos. Por ejemplo, cuando llamas math.sin pasas un número como argumento. Algunas funciones toman más de un argumento: math.pow toma dos, la base y el exponente.

# %%
def addtwo(a, b):
    added = a + b
    return added

x = addtwo(3, 5)
print(x)

# %% [markdown]
# ## Funciones fructíferas y funciones nulas
#
# Algunas de las funciones que utilizamos, como las funciones matemáticas, producen resultados. A falta de un nombre mejor, las llamo funciones fructíferas. Otras funciones, como print_twice, realizan una acción pero no devuelven un valor. Se les llama funciones nulas (void functions).

# %%
result = print('Bing')
print(result)

# %% [markdown]
# ## ¿Para qué crear funciones?
#
# Puede que no esté claro por qué vale la pena dividir un programa en funciones. Hay varias razones:
# * La creación de una nueva función le brinda la oportunidad de nombrar un grupo de declaraciones, lo que hace que su programa sea más fácil de leer, comprender y depurar.
# * Las funciones pueden hacer que un programa sea más pequeño eliminando el código repetitivo. Más tarde, si realiza un cambio, solo tendrá que hacerlo en un lugar.
# * La división de un programa largo en funciones le permite depurar las partes una a la vez y luego ensamblarlas en un todo de trabajo.
# * Las funciones bien diseñadas suelen ser útiles para muchos programas. Una vez que escribes y depuras una, puedes reutilizarla.

# %% [markdown]
# ### Las variables pueden tener ámbito local o global.
#
# #### Local Scope. Ámbito local.
#
# - Las variables declaradas dentro de una función, por ejemplo, solo pueden existir dentro del bloque.
# - Una vez que se sale del bloque, las variables se vuelven inaccesibles.

# %%
def some_funcion():
  TestMode = False

print(TestMode)

# %% [markdown]
# En Python, if else y for/while loops block crean variables de ámbito global.

# %%
for i in range(1, 11):
    test_scope = "variable inside for loop"
    
print(test_scope)

# %% [markdown]
# Con el bloque if-else:

# %%
is_python_awesome = True

if is_python_awesome:
    test_scope = "Python is awesome"

print(test_scope)

# %% [markdown]
# #### Global Scope. Ámbito global.
#
# - Las variables a las que se puede acceder desde cualquier función tienen un ámbito global.
# - Puedes declarar una variable global fuera de las funciones. Es importante tener en cuenta que para asignar un nuevo valor a una variable global, deberás utilizar la palabra clave “**global**”:

# %%
TestMode = True

def some_function():
  global TestMode
  TestMode = False
    
some_function()
print(TestMode) # Returns False

# %% [markdown]
# > Al eliminar la línea "global TestMode" solo se establecerá la variable en False dentro de la función some_function().

# %% [markdown]
# ### Ejercicio 4
#
# Reescribe tu cálculo de pago con tiempo y medio para horas extras y crea una función llamada computepay que tome dos parámetros (hours y rate).
#
# ```
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0
# ```

# %% [markdown]
# # Bucles
#
# Los ordenadores se utilizan a menudo para automatizar tareas repetitivas. Repetir tareas idénticas o similares sin cometer errores es algo que a los ordenadores se les da muy bien y a las personas se les da muy mal. Debido a que la iteración es tan común, Python proporciona varias características de lenguaje para que sea más fácil.

# %% [markdown]
# ## while loop

# %%
n = 5
while n > 0:
    print(n)
    n = n - 1
print('Blastoff!')

# %% [markdown]
# ### Cuidado con los bucles infinitos

# %%
#n = 10
#while True:
#    print(n, end=' ')
#    n = n - 1
#print('Done!')

# %% [markdown]
# ### Finalización de iteraciones con `continue`

# %%
while True:
    line = input('> ')
    if line[0] == '#':
        continue
    if line == 'done':
        break
    print(line)
print('Done!')

# Code: http://www.py4e.com/code3/copytildone2.py
# Or select Download from this trinket's left-hand mebnu

# %% [markdown]
# ## Bucles definidos usando `for`

# %%
friends = ['Joseph', 'Glenn', 'Sally']
for friend in friends:
    print('Happy New Year:', friend)
print('Done!')

# %% [markdown]
# ### Ejemplos

# %%
# Bucle de suma y recuento

# recuento
count = 0
for itervar in [3, 41, 12, 9, 74, 15]:
    count = count + 1
print('Count: ', count)

# suma
total = 0
for itervar in [3, 41, 12, 9, 74, 16]:
    total = total + itervar
print('Total: ', total)

# %%
# Bucles máximos y mínimos
largest = None
print('Before:', largest)
for itervar in [3, 41, 12, 9, 74, 15]:
    if largest is None or itervar > largest :
        largest = itervar
    print('Loop:', itervar, largest)
print('Largest:', largest)

# %% [markdown]
# ### Ejercicio 5
#
# Escribe un programa que lea números repetidamente hasta que el usuario ingrese "listo". Una vez que se ingrese "listo", imprima el total, el recuento y el promedio de los números. Si el usuario ingresa algo que no sea un número, detecta su error usando try y except e imprime un mensaje de error y salta al siguiente número.
#
# ```bash
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333
# ```

# %%
condicion = True
total = 0

while condicion:
  number = input('introduce un número ')
  if number != 'done':
    try:
      number = int(number)
      total = total + number
    except:
      print('Dato malo')
  
  elif number == 'done':
    condicion = False

print('El total es', total)
# Out:
# introduce un número 4
# introduce un número 5
# introduce un número asdf
# Dato malo
# introduce un número done
# El total es 9

# %% [markdown]
# # Cadenas

# %% [markdown]
# - Información textual. Las cadenas son una secuencia de letras.
# - El valor de la cadena se incluye entre comillas:
#
# ```python
# name = 'farhad'
# ```
#
# - Las cadenas son inmutables. Una vez que se crean, no se pueden cambiar.

# %%
a = 'me'
a[1]='y'

# %% [markdown]
# ## Atravesar una cadena con un bucle

# %%
fruta = 'plátano'
for letra in fruta:
    print(letra)

# %% [markdown]
# ## Operaciones con cadenas
#
# - Concatenando cadenas:

# %%
'A' + 'B'

# %% [markdown]
# - Repetir cadenas

# %%
'A'* 3

# %% [markdown]
# - Troceando cadenas (slicing)

# %%
y = 'Abc'
print(y[:2])
print(y[1:])
print(y[:-2]) # índice negativo
print(y[-2:]) # índice negativo

# %% [markdown]
# - Revertir el orden

# %%
x = 'abc'
x[::-1]

# %% [markdown]
# - Encontrando el índice

# %%
name = 'farhad'
index1 = name.find('r')
print('Index 1 es ',index1)

name = 'farhad'
index2 = name.find('a', 2) # finds index of second a
print('Index 2 es ',index2)

# %% [markdown]
# - split(): divide una cadena en una lista.
# - replace(): reemplaza la cadena coincidente.

# %%
texto = '2 saxofonistas tocan con 3 clarinetistas'
texto.split()

# %%
texto.replace('2', 'dos')

# %% [markdown]
# ## El operador `in`

# %%
'a' in 'banana'
True
'seed' in 'banana'
False

# %% [markdown]
# ## Comparación de cadenas

# %%
word = input('Introduce una palabra: ')

if word < 'banana':
    print('Your word,' + word + ', comes before banana.')
elif word > 'banana':
    print('Your word,' + word + ', comes after banana.')
else:
    print('All right, bananas.')

# %% [markdown]
# ## Métodos de cadena

# %%
saludo = 'Hola, mundo'
type(saludo)
dir(saludo)

# %% [markdown]
# Mientras que la función dir enumera los métodos, y puedes usar help para obtener alguna documentación simple sobre un método, una mejor fuente de documentación para los métodos de cadena sería https://docs.python.org/3.7/library/stdtypes.html#string-methods.

# %% [markdown]
# ## Parseando cadenas
#
# Imagina que queremos obetener el dominio desde el que se ha enviado un mail a partir de la siguiente línea `From`:
#
# `From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008`

# %%
data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
atpos = data.find('@')
print('La posición de la arroba es ', atpos)
sppos = data.find(' ',atpos)
print('La posición del espacio es ', sppos)
host = data[atpos+1:sppos]
print('El dominio del mail del remitente es ', host)

# %% [markdown]
# ## Operador de formato
#
# ```python
# >>> camels = '42'
# >>> '%d' % camels
# 42
# ```
#
# En Python 3.7 ha avanzado mucho la manera de formatear cadenas. En el siguiente enlace tenéis más información.
#
# https://realpython.com/python-f-strings/

# %% [markdown]
# ### Ejercicio 6
#
# Toma el siguiente código de Python que almacena una cadena:
#
# `str = 'X-DSPAM-Confidence: 0.8475'`
#
# Usa find y el corte de cadena para extraer la parte de la cadena después del caracter de dos puntos y luego use la función float para convertir la cadena extraída en un número de punto flotante.

# %%
cadena = 'X-DSPAM-Confidence: 0.8475'

apos = cadena.find(' ')
print(float(cadena[apos:]))
# Out:
# 0.8475

# %% [markdown]
# # Archivos
#
# Haciendo persistente la información (en archivos de texto de momento)

# %%
impo
# Out:
#   File "<ipython-input-20-34876f9b08f0>", line 2
#     file.write(str(i))
#     ^
# IndentationError: unexpected indent

# %%
import requests
from bs4 import BeautifuSoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-4dd6e1b28419> in <module>()
#       1 import requests
# ----> 2 from bs4 import BeautifuSoup
#
# ImportError: cannot import name 'BeautifuSoup'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Ejercicio 7
#
# Escribe un programa para leer un archivo e imprime sólo las líneas que comiencen por FROM.

# %% [markdown]
# # Listas
#
# Como una cadena, una lista es una secuencia de valores. En una cadena, los valores son caracteres; en una lista, pueden ser de cualquier tipo. Los valores en la lista se denominan elementos.
# Hay varias formas de crear una nueva lista; lo más simple es encerrar los elementos entre corchetes ([ y ]):
#
# ```python
# [10, 20, 30, 40]
# ['crunchy frog', 'ram bladder', 'lark vomit']
# ```
#
# Los elementos de una lista no tienen que ser del mismo tipo. La siguiente lista contiene una cadena, un decimal, un entero y... ¡otra lista!:
#
# ```python
# ['spam', 2.0, 5, [10, 20]]
# ```

# %% [markdown]
# ## Las listas son mutables
#
# ```python
# >>> numbers = [17, 123]
# >>> numbers[1] = 5
# >>> print(numbers)
# [17, 5]
# >>>
# ```

# %% [markdown]
# ## El operador `in`
#
# ```python
# >>> cheeses = ['Cheddar', 'Edam', 'Gouda']
# >>> 'Edam' in cheeses
# True
# >>> 'Brie' in cheeses
# False
# >>>
# ```

# %% [markdown]
# ## Atravesando una lista

# %%
cheeses = ['Cheddar', 'Edam', 'Gouda']

for cheese in cheeses:
    print(cheese)

# %% [markdown]
# ## Operaciones de lista

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b
print(c)

# %% [markdown]
# Del mismo modo, el operador * repite una lista un número determinado de veces:

# %% [markdown]
# ## Listar segmentos

# %%
t = ['a', 'b', 'c', 'd', 'e', 'f']
print(t[1:3])
print(t[:4])
print(t[3:])

# %% [markdown]
# ## Copiando una lista
#
# Las listas son referencias a un punto en la memoria no espacios de memoria en sí mismos.

# %%
a = t[:]

# %% [markdown]
# ## Métodos de lista

# %%
t = ['a', 'b', 'c']
t.append('d')
print(t)

# %%
t = ['a', 'b', 'c']
t.extend(['d', 'f'])
print(t)

# %%
t = ['d', 'c', 'e', 'b', 'a']
t.sort()
print(t)

# %% [markdown]
# ## Eliminando elementos

# %%
t = ['a', 'b', 'c']
x = t.pop(1)
print(t)
print(x)

# %% [markdown]
# Si no necesitas el valor eliminado, puede usar el operador `del`:

# %%
t = ['a', 'b', 'c']
del t[1]
print(t)

# %% [markdown]
# Si conoces el elemento que deseas eliminar (pero no el índice), puedes usar `remove`:

# %%
t = ['a', 'b', 'c']
t.remove('b')
print(t)

# El valor de retorno de remove es None.

# %% [markdown]
# Para eliminar más de un elemento, puedes usar del con un índice de división:

# %%
t = ['a', 'b', 'c', 'd', 'e', 'f']
del t[1:5]
print(t)

# %% [markdown]
# ## Listas y funciones
#
# Hay una serie de funciones incorporadas que se pueden usar en listas que te permiten mirar rápidamente una lista sin escribir sus propios bucles:
#
# ```python
# >>> nums = [3, 41, 12, 9, 74, 15]
# >>> print(len(nums))
# 6
# >>> print(max(nums))
# 74
# >>> print(min(nums))
# 3
# >>> print(sum(nums))
# 154
# >>> print(sum(nums)/len(nums))
# 25.666666666666668
# ```

# %% [markdown]
# ## Listas y cadenas

# %%
s = 'spam'
t = list(s)
print(t)

# %%
s = 'pining for the fjords'
t = s.split()
print(t,'\n----------')
print(t[2])

# %%
s = 'spam-spam-spam'
delimiter = '-'
s.split(delimiter)

# %%
s = 'spam-spam-spam'
delimiter = '-'
s.split(delimiter)

# %% [markdown]
# ## Parseando líneas

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    line = line.rstrip()
    if not line.startswith('From '): continue
    words = line.split()
    print(words[2])

# Code: http://www.py4e.com/code3/search5.py
# Or select Download from this trinket's left-hand menu

# %% [markdown]
# ### Ejercicio 8
#
# Escribe un programa para abrir el archivo romeo.txt y léelo línea por línea. Para cada línea, divide la línea en una lista de palabras usando la función split.
# Para cada palabra, verifica si la palabra ya está en una lista. Si la palabra no está en la lista, agrégala a la lista.
#
# Cuando se complete el programa, ordena e imprime las palabras resultantes en orden alfabético.
#
# ```bash
# Enter file: romeo.txt
#
# ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']
# ```

# %% [markdown]
# # Diccionarios
#
# Un diccionario es como una lista, pero más general. En una lista, las posiciones del índice deben ser enteros. En un diccionario, los índices pueden ser (casi) de cualquier tipo.
#
# Puedes pensar en un diccionario como una asignación entre un conjunto de índices (que se denominan claves) y un conjunto de valores. Cada valor se asigna a una clave. La asociación de una clave y un valor se denomina par clave-valor o, a veces, un elemento.
#
# La función dict crea un nuevo diccionario sin elementos. Como dict es el nombre de una función incorporada, debes evitar usarla como nombre de variable.
#
# ```python
# named_variable = dict()
# # También puedes crear un diccionario de la siguiente manera
# named_variable_2 = {}
# ```
#
# Las llaves, {}, representan un diccionario vacío. Para agregar elementos al diccionario, puede usar corchetes:
#
# ```python
#  named_variable['one'] = 'uno'
# ```

# %% [markdown]
# La línea anterior línea crea un elemento que se asigna desde la clave 'one' al valor "uno". Si imprimimos el diccionario nuevamente, vemos un par clave-valor con dos puntos entre la clave y el valor:
#
# ```python
# >>> print(named_variable)
# {'one': 'uno'}
#
# >>> eng2sp = {'one': 'uno', 'two': 'dos', 'three': 'tres'}
# >>> print(eng2sp)
# {'one': 'uno', 'three': 'tres', 'two': 'dos'}
# ```
#
# La clave 'two' siempre contiene el valor "dos", por lo que el orden de los elementos no importa. Con los diccionarios también funcionan los operadores `len`e `in`.

# %% [markdown]
# ## Diccionario como conjunto de contadores

# %%
word = 'brontosaurus'
d = {}
for c in word:
  if c not in d:
    d[c] = 1
  else:
    d[c] = d[c] + 1
print(d)

# %% [markdown]
# ## Método get
#
# Los diccionarios tienen un método llamado get que toma una clave y un valor predeterminado. Si la clave aparece en el diccionario, get devuelve el valor correspondiente; de lo contrario, devuelve el valor predeterminado. Por ejemplo:

# %%
>>> counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
>>> print(counts.get('jan', 0))

# %%
>>> print(counts.get('tim', 0))

# %% [markdown]
# ## Diccionarios y archivos
#
# Escribiremos un programa en Python para leer las líneas del archivo, dividir cada línea en una lista de palabras y luego recorrer cada una de las palabras en la línea y contar cada palabra con un diccionario.

# %%
fname = input('Enter the file name: ')
try:
    fhand = open(fname)
except:
    print('File cannot be opened:', fname)
    exit()

counts = dict()
for line in fhand:
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1

print(counts)

# Code: http://www.py4e.com/code3/count1.py
# Or select Download from this trinket's left-hand menu

# %% [markdown]
# ## Bucles y diccionarios
#
# Si utilizas un diccionario como la secuencia en una instrucción for, atraviesa las claves del diccionario. Este bucle imprime cada clave y el valor correspondiente:

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
for key in counts:
    print(key, counts[key])

# %% [markdown]
# Si deseas imprimir las claves en orden alfabético, primero haz una lista de las claves en el diccionario usando el método keys disponible en los objetos de tipo diccionario, y luego ordena esa lista y recorre la lista ordenada, mirando cada clave e imprimiendo pares clave-valor ordenados de la siguiente manera:

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
lst = list(counts.keys())
print(lst)
lst.sort()
for key in lst:
    print(key, counts[key])

# %% [markdown]
# ## Análisis de texto avanzado
#
# En el ejemplo anterior usando el archivo romeo.txt, hicimos el archivo lo más simple posible eliminando toda puntuación a mano. El texto real tiene mucha puntuación, como se muestra a continuación.
#
# ```
# But, soft! what light through yonder window breaks?
# It is the east, and Juliet is the sun.
# Arise, fair sun, and kill the envious moon,
# Who is already sick and pale with grief,
# ```
#
# Podemos resolver ambos problemas utilizando los métodos de cadena `lower`, ` punctuation` y `translate`. `translate` es el más sutil de los métodos. Aquí está la documentación para translate:
#
# ```line.translate(str.maketrans(fromstr, tostr, deletestr))```
#
# Reemplaza los caracteres en fromstr con el carácter en la misma posición en tostr y borra todos los caracteres que estén en deletestr. Fromstr y tostr pueden ser cadenas vacías y el parámetro deletestr puede omitirse.

# %%
>>> import string
>>> string.punctuation

# %%
import string

fname = input('Enter the file name: ')
try:
    fhand = open(fname)
except:
    print('File cannot be opened:', fname)
    exit()

counts = dict()
for line in fhand:
    line = line.rstrip()
    line = line.translate(line.maketrans('', '', string.punctuation))
    line = line.lower()
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1

print(counts)

# %% [markdown]
# ### Ejercicio 9
#
# Escribe un programa que categorice cada mensaje de correo según el día de la semana en que se realizó la confirmación. Para hacer esto, busca líneas que comiencen con "From", luego busca la tercera palabra y manten un conteo de cada uno de los días de la semana. Al final del programa, imprime el contenido de tu diccionario (el orden no importa).
# Línea de muestra:
#
# `From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008`
#
# Ejecución de la muestra:
#
# ```bash
# python dow.py
# Enter a file name: mbox-short.txt
# {'Fri': 20, 'Thu': 6, 'Sat': 1}
# ```

# %% [markdown]
# # Tuplas
#
# ## Las tuplas son inmutables
#
# Una tupla1 es una secuencia de valores muy parecida a una lista. Los valores almacenados en una tupla pueden ser de cualquier tipo, y están indexados por enteros. La diferencia importante es que las tuplas son inmutables. Las tuplas también son comparables y hashables, por lo que podemos ordenar las listas y usar tuplas como valores en los diccionarios de Python.
#
# Aunque no es necesario, es común incluir tuplas entre paréntesis para ayudarnos a identificar tuplas rápidamente cuando observamos el código de Python:
#
# ```python
# t = ('a', 'b', 'c', 'd', 'e')
# ```

# %%
>>> t = tuple('lupins')
>>> print(t)

# %%
>>> t = tuple('lupins')
>>> print(t)

# %% [markdown]
# ## ¿Qué hace este código?

# %%
txt = 'but soft what light in yonder window breaks'
words = txt.split()
t = list()
for word in words:
    t.append((len(word), word))

t.sort(reverse=True)

res = list()
for length, word in t:
    res.append(word)

print(res)

# Code: http://www.py4e.com/code3/soft.py

# %% [markdown]
# ## Asignación rápida de valores

# %%
m = ('cero', 'uno')
x, y = m
print('x es igual a', x)
print('y es igual a', y)

# %% [markdown]
# ## Swapping de valores (intercambiando valores)

# %%
x, y = y, x
print('x es igual a', x)
print('y es igual a', y)

# %%
addr = 'monty@python.org'
uname, domain = addr.split('@')
print('El usuario es {}, escribiendo desde el dominio {}'.format(uname, domain))

# %% [markdown]
# ## Diccionarios y tuplas
#
# Los diccionarios tienen un método llamado items que devuelve una lista de tuplas, donde cada tupla es un par clave-valor:

# %%
d = {'a':10, 'b':1, 'c':22}
t = list(d.items())
print(t)

# %% [markdown]
# ### Asignación múltiple con diccionarios
#
# Combinando items, asignación de tuplas y for, puedes ver un bonito patrón de código para recorrer las claves y los valores de un diccionario en un solo bucle:

# %%
d = {'a':10, 'b':1, 'c':22}
l = list()
for key, val in d.items() :
    l.append((val, key))

print(l)

l.sort(reverse=True)

print(l)

# %% [markdown]
# ### Gracias a las tuplas ordenamos diccionarios

# %%
import string
fhand = open('romeo-full.txt')
counts = dict()
for line in fhand:
    line = line.translate(str.maketrans('', '', string.punctuation))
    line = line.lower()
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1

# Sort the dictionary by value
lst = list()
for key, val in list(counts.items()):
    lst.append((val, key))

lst.sort(reverse=True)

for key, val in lst[:10]:
    print(key, val)

# %% [markdown]
# ### Ejercicio 10
#
# Revisa tu programa anterior de la siguiente manera: Lee y analiza las líneas "From" y saca el día de la semana de la línea. Cuenta el número de mensajes para cada día usando un diccionario.
#
# Después de haber leído todos los datos, imprime el día con el mayor número de confirmaciones creando una lista de tuplas (conteo, correo electrónico) del diccionario. Luego, ordena la lista en orden inverso e imprime el día en el que se envían más mensajes.

# %% [markdown]
# # Objetos
#
# Son abstracciones que creamos para organizar la resolución de un problema o representar la realidad con la que queremos trabajar. Nos ayudan a segmentar un problema y a ocultar la complejidad, distribuyéndola por capas.

# %%
class Gallo():
    def __init__(self, color, raza):
        self.patas = 2 # atributo
        self.cresta = 1  # atributo
        self.color = color # atributo
        self.raza = raza   # atributo: Menorca o Houdan
        
    def cacarea_y_saluda(self, name):
        print('Kikirikí,', name)
        
gallo_1 = Gallo('blanco', 'Menorca')
gallo_1.cacarea_y_saluda('Jesús')

# %%
type(gallo_1)

# %%
dir(gallo_1)

# %% [markdown]
# # Usos de Python

# %% [markdown]
# ## Web Scraping
#
# * No lo muestro con orgullo, pero [aquí](https://github.com/catedu/exeLearning_toGitbook) tenéis una muestra de su uso como programador pincipiante.
# * [Aquí](https://github.com/deleyva/automatiza-tu-aprendizaje/blob/master/scrap.py) tenéis otro ejemplo con el que he traducido y reformateado el curso de Python for Everybody.

# %% [markdown]
# ### Otro ejemplo de web-scraping usnando pandas

# %%
import pandas as pd
import requests
from bs4 import *
from csv import reader
import re

df = pd.read_html('http://arablogs.catedu.es/buscar.php')[0]

# %%
df.head()
# Out:
#    Id Blog          Título Blog  \
# 0        1     CATEDU "Blogggg"
# 1       30       Infantil Ateca
# 2       32  CPEE Gloria Fuertes
# 3       38    C.E.E. LA ALEGRÍA
# 4       42  P.C.P.I. LA ALEGRÍA
#
#                                            Subtítulo  \
# 0  Una "nueva" "forma" de leer y escribir con las...
# 1                                Jesús Gil Alejandre
# 2                                 Un blog para todos
# 3                                             Monzón
# 4                                             MONZÓN
#
#                                          Descripcion  \
# 0  Blog de pruebas utilizado por el CATEDU "para ...
# 1  Blog sobre actividades y curiosidades realizad...
# 2  En este Blog los alumnos/as del colegio nos co...
# 3      Blog de nuestro C.E.E. La Alegría, en Monzón.
# 4  Blog de los Alumnos de P.C.P.I.(Programa de Ca...
#
#                   Responsable  \
# 0  de AraBlogs, Administrador
# 1        Gil Alejandre, Jesús
# 2     Fuertes Andorra, Gloria
# 3    La Alegría Monzón, C.E.E
# 4    La Alegría Monzón, C.E.E
#
#                                               Centro Localidad
# 0  CATEDU Centro Aragonés de Tecnologías para la ...  Alcorisa
# 1                              CP Virgen De La Peana     Ateca
# 2                                 CEE Gloria Fuertes   Andorra
# 3                                     CEE La Alegría    Monzon
# 4                                     CEE La Alegría    Monzon

# %%
with open('bolgs.csv', 'w'):
    dfs.to_csv('bolgs.csv')

# %% [markdown]
# ### Ejercicio 11
#
# En esta tarea, escribirás un programa en Python que se expande en http://www.py4e.com/code3/urllinks.py. El programa utilizará urllib para leer el HTML de los archivos de datos a continuación, extraer los valores de href= de las etiquetas de anclaje, buscar una etiqueta que se encuentre en una posición particular en relación con el primer nombre en la lista, seguir ese enlace y repetir el proceso varias veces, informando del último nombre que encuentre.
#
# Comienca en http://py4e-data.dr-chuck.net/known_by_Fikret.html. Encuentra el enlace en la posición 3 (el primer nombre es 1). Sigue ese enlace. Repite este proceso 4 veces. La respuesta es el último nombre que recuperas. Secuencia de nombres: Fikret Montgomery Mhairade Butchi Anayah. Último nombre en la secuencia: Anayah

# %% [markdown]
# ## Servicios Web

# %%
import requests
import json

r = requests.get('https://es.wallapop.com/rest/items?_p=1&dist=400&publishDate=any&orderBy=distance&orderType=asc&latitude=41.65&longitude=-0.88333')
data = json.loads(r.text)
data
# Out:
# {'chatUrl': 'https://web.wallapop.com',
#  'distanceFromYou': 1,
#  'emptySearch': False,
#  'items': [{'activeItemPurchases': None,
#    'bumpType': 'countrybump',
#    'categoryId': 12467,
#    'content': 'canape abatible tapizado 3d madera nuevo 681046901 / 854707460 (llamadas y whatsapp) nuevos directos de fábrica!! 2 años de garantia descripcion base tapizada 3d acolchada con un refuerzo de 1cm de espuma para conseguir un mayor confort. fabricada en tubo de acero de 30x40, dispone de tirador y arquillo para evitar desplazamientos del colchón en su apertura. patas macizas de madera de haya con 3 cm de grosor y 11 de ancho fondos fabricados en tablero de 0.80cm capacidad de almacenaje 29cm, altura total del canapé 36,5cm. dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completo',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': '681046901 / 854707460 (Llamadas y whatsapp) NUEVOS DIRECTOS DE FÁBRICA!! 2 AÑOS DE GARANTIA DESCRIPCION Base tapizada 3D acolchada con un refuerzo de 1cm de espuma para conseguir un mayor confort. Fabricada en tubo de acero de 30x40, Dispone de tirador y arquillo para evitar desplazamientos del colchón en su apertura. Patas macizas de madera de haya con 3 cm de grosor y 11 de ancho Fondos fabricados en tablero de 0.80cm Capacidad de almacenaje 29cm, altura total del canapé 36,5cm. dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completo',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': '9ea4d3',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 800918276,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'e4e9ed',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i464277102.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i464277102.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 464277102,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i464277102.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i464277102.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'ebeaea',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i679316576.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i679316576.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 679316576,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i679316576.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i679316576.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 206784525,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': 'mzngg93oyy6n',
#    'location': {'address': '',
#     'approximated_latitude': 40.41222250933474,
#     'approximated_location': True,
#     'approximated_longitude': -3.696214355333434,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.030625369648843777,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4167754,
#     'longitude': -3.7037902,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': '9ea4d3',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W640',
#     'mobileScaledRatio': 75.0,
#     'originalHeight': 1200,
#     'originalWitdh': 1600,
#     'pictureId': 800918276,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 165,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/3f/43/__/c10420p206784525/i800918276.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '139 €',
#    'publishDate': 1518435619000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 139,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'kp61e7xo2xz5',
#     'image': {'averageHexColor': 'd9d9da',
#      'bigURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W640',
#      'mobileScaledRatio': 44.44444477558136,
#      'originalHeight': 256,
#      'originalWitdh': 576,
#      'pictureId': 541662630,
#      'smallURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 97,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Dhome M.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'dolores-80941055',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '20 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 0,
#      'selledCount': 3,
#      'sellingCount': 20,
#      'sellsCount': 3,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/dolores-80941055',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 80941055,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'CANAPE ABATIBLE TAPIZADO 3D MADERA NUEVO',
#    'url': 'canape-abatible-madera-206784525',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'countrybump',
#    'categoryId': 12467,
#    'content': 'canape abatible + colchon + almohada nuevo 681046901 / 854707460 (llamadas y whatsapp) nuevos directos de fábrica!! alta calidad matrimonio - individual 2 años de garantia dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completa comodas',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': '681046901 / 854707460 (Llamadas y whatsapp) NUEVOS DIRECTOS DE FÁBRICA!! ALTA CALIDAD MATRIMONIO - INDIVIDUAL 2 AÑOS DE GARANTIA dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completa comodas',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': 'c5c8e6',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 800905307,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'e8ebf1',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679455081.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679455081.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 679455081,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679455081.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679455081.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'f1f2f3',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679460595.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679460595.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 679460595,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679460595.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679460595.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'ebeaea',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679456738.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679456738.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 679456738,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679456738.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i679456738.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 255353423,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': 'ejkxexq3v16x',
#    'location': {'address': '',
#     'approximated_latitude': 40.41222250933474,
#     'approximated_location': True,
#     'approximated_longitude': -3.696214355333434,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.030625369648843777,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4167754,
#     'longitude': -3.7037902,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': 'c5c8e6',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W640',
#     'mobileScaledRatio': 75.0,
#     'originalHeight': 1200,
#     'originalWitdh': 1600,
#     'pictureId': 800905307,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 165,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/48/13/__/c10420p255353423/i800905307.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '225 €',
#    'publishDate': 1534936389000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 225,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'kp61e7xo2xz5',
#     'image': {'averageHexColor': 'd9d9da',
#      'bigURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W640',
#      'mobileScaledRatio': 44.44444477558136,
#      'originalHeight': 256,
#      'originalWitdh': 576,
#      'pictureId': 541662630,
#      'smallURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 97,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Dhome M.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'dolores-80941055',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '20 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 0,
#      'selledCount': 3,
#      'sellingCount': 20,
#      'sellsCount': 3,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/dolores-80941055',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 80941055,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'CANAPE ABATIBLE + COLCHON + ALMOHADA NUEVO',
#    'url': 'canape-abatible-colchon-almohada-nuevo-255353423',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'countrybump',
#    'categoryId': 12467,
#    'content': 'pack canape + colchon nuevo 681046901 / 854707460 (llamadas y whatsapp) nuevos directos de fábrica!! alta calidad matrimonio - individual 2 años de garantia dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completo',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': '681046901 / 854707460 (Llamadas y whatsapp) NUEVOS DIRECTOS DE FÁBRICA!! ALTA CALIDAD MATRIMONIO - INDIVIDUAL 2 AÑOS DE GARANTIA dormitorio de matrimonio o individual barato económico gran capacidad madera tapizado canapé completo',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': 'c3c7e5',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 800916319,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'e8ebf1',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688449246.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688449246.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 688449246,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688449246.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688449246.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'f1f2f3',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451236.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451236.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 688451236,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451236.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451236.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'f1f2f3',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688454754.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688454754.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 1200,
#      'originalWitdh': 1600,
#      'pictureId': 688454754,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688454754.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688454754.jpg?pictureSize=W1024'},
#     {'averageHexColor': 'ebeaea',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451240.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451240.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 688451240,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451240.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i688451240.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 304798493,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': '3zl47mwx48jx',
#    'location': {'address': '',
#     'approximated_latitude': 40.41222250933474,
#     'approximated_location': True,
#     'approximated_longitude': -3.696214355333434,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.030625369648843777,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4167754,
#     'longitude': -3.7037902,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': 'c3c7e5',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W640',
#     'mobileScaledRatio': 75.0,
#     'originalHeight': 1200,
#     'originalWitdh': 1600,
#     'pictureId': 800916319,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 165,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/51/gw/__/c10420p304798493/i800916319.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '215 €',
#    'publishDate': 1544011339000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 215,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'kp61e7xo2xz5',
#     'image': {'averageHexColor': 'd9d9da',
#      'bigURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W640',
#      'mobileScaledRatio': 44.44444477558136,
#      'originalHeight': 256,
#      'originalWitdh': 576,
#      'pictureId': 541662630,
#      'smallURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 97,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/1c/6u/__/c13p80941055/i541662630.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Dhome M.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'dolores-80941055',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '20 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 0,
#      'selledCount': 3,
#      'sellingCount': 20,
#      'sellsCount': 3,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/dolores-80941055',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 80941055,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'Pack canape + colchon NUEVO',
#    'url': 'pack-canape-colchon-nuevo-304798493',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'citybump',
#    'categoryId': 12467,
#    'content': 'sofá sofá de diseño en perfecto estado. uno de los módulos tiene opción de almacenamiento. acepto ofertas. vendo por mudanza',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': 'Sofá de diseño en perfecto estado. Uno de los módulos tiene opción de almacenamiento. Acepto ofertas. Vendo por mudanza',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': '636a6c',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 793638306,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W1024'},
#     {'averageHexColor': '677075',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793640285.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793640285.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 793640285,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793640285.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793640285.jpg?pictureSize=W1024'},
#     {'averageHexColor': '6b7173',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793629755.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793629755.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 900,
#      'originalWitdh': 1200,
#      'pictureId': 793629755,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793629755.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793629755.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 341950893,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': '3zl43vwe2qjx',
#    'location': {'address': '28004 Madrid, España',
#     'approximated_latitude': 40.417735814002086,
#     'approximated_location': True,
#     'approximated_longitude': -3.7046063849237827,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.9761898165506566,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.425785,
#     'longitude': -3.703987,
#     'neighborhood': None,
#     'postal_code': '28015',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': '636a6c',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W640',
#     'mobileScaledRatio': 75.0,
#     'originalHeight': 900,
#     'originalWitdh': 1200,
#     'pictureId': 793638306,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 165,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/5n/l6/__/c10420p341950893/i793638306.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '399 €',
#    'publishDate': 1553513226000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 399,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'g0j2yvqddrzy',
#     'image': {'averageHexColor': '5d6369',
#      'bigURL': 'https://cdn.wallapop.com/images/13/0d/ba/__/c13p22362411/i468567424.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/0d/ba/__/c13p22362411/i468567424.jpg?pictureSize=W640',
#      'mobileScaledRatio': 100.0,
#      'originalHeight': 1024,
#      'originalWitdh': 1024,
#      'pictureId': 468567424,
#      'smallURL': 'https://cdn.wallapop.com/images/13/0d/ba/__/c13p22362411/i468567424.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 220,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/0d/ba/__/c13p22362411/i468567424.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Guio R.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'guiomarr-22362411',
#     'statsUser': {'buysCount': 1,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '15 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 17,
#      'selledCount': 12,
#      'sellingCount': 15,
#      'sellsCount': 26,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/guiomarr-22362411',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 22362411,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'Sofá',
#    'url': 'sofa-341950893',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'citybump',
#    'categoryId': 12467,
#    'content': "¡¡negociable!! sofá cheslong nuevo, oportunidad!! sofá cheslong de 5 plazas nuevo. de marca y diseño italiano. tapizado color gris oscuro. la pieza cheslong se encaja en el lado derecho fácilmente. *largo completo de extremo a extremo 2'60 metros. *ancho/fondo asientos incluyendo respaldo 0'95 metros *cheslong 1'15 metros de ancho incluyendo reposa brazos y largo 1'75 metros *ancho reposa brazos 0'22 metros *ancho respaldo 0'25 metros *altura desde el suelo 0'35 metros y 0'70 metros se encuentra en perfecto estado y habiendo tenido muy poco uso se vende por mudanza. precio original 2.175€",
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': "Sofá cheslong de 5 plazas nuevo. De marca y diseño italiano. Tapizado color gris oscuro. La pieza cheslong se encaja en el lado derecho fácilmente. *Largo completo de extremo a extremo 2'60 metros. *Ancho/fondo asientos incluyendo respaldo 0'95 metros *Cheslong 1'15 metros de ancho incluyendo reposa brazos y largo 1'75 metros *Ancho reposa brazos 0'22 metros *Ancho respaldo 0'25 metros *Altura desde el suelo 0'35 metros y 0'70 metros Se encuentra en perfecto estado y habiendo tenido muy poco uso se vende por MUDANZA. Precio original 2.175€",
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': '858482',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778445874,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W1024'},
#     {'averageHexColor': '838280',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474385.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474385.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778474385,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474385.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474385.jpg?pictureSize=W1024'},
#     {'averageHexColor': '878887',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778447780.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778447780.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778447780,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778447780.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778447780.jpg?pictureSize=W1024'},
#     {'averageHexColor': '7c7f7f',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474392.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474392.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778474392,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474392.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778474392.jpg?pictureSize=W1024'},
#     {'averageHexColor': '7b8183',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778451713.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778451713.jpg?pictureSize=W640',
#      'mobileScaledRatio': 133.33333730697632,
#      'originalHeight': 800,
#      'originalWitdh': 600,
#      'pictureId': 778451713,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778451713.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 293,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778451713.jpg?pictureSize=W1024'},
#     {'averageHexColor': '968b86',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778444089.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778444089.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778444089,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778444089.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778444089.jpg?pictureSize=W1024'},
#     {'averageHexColor': '898784',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778465405.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778465405.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 600,
#      'originalWitdh': 800,
#      'pictureId': 778465405,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778465405.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778465405.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 336809348,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': 'e65vo7gyr0jo',
#    'location': {'address': '',
#     'approximated_latitude': 40.4167754,
#     'approximated_location': False,
#     'approximated_longitude': -3.7037902,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.030625369648843777,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4167754,
#     'longitude': -3.7037902,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': '858482',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W640',
#     'mobileScaledRatio': 75.0,
#     'originalHeight': 600,
#     'originalWitdh': 800,
#     'pictureId': 778445874,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 165,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/5k/iz/__/c10420p336809348/i778445874.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '690 €',
#    'publishDate': 1552336578000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 690.0,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'npj9nolg0oze',
#     'image': {'averageHexColor': '9bb2b3',
#      'bigURL': 'https://cdn.wallapop.com/images/13/11/g6/__/c13p62901261/i430892551.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/11/g6/__/c13p62901261/i430892551.jpg?pictureSize=W640',
#      'mobileScaledRatio': 56.25,
#      'originalHeight': 450,
#      'originalWitdh': 800,
#      'pictureId': 430892551,
#      'smallURL': 'https://cdn.wallapop.com/images/13/11/g6/__/c13p62901261/i430892551.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 123,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/11/g6/__/c13p62901261/i430892551.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Alanitos G.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'luciag-62901261',
#     'statsUser': {'buysCount': 1,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '8 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 15,
#      'selledCount': 20,
#      'sellingCount': 8,
#      'sellsCount': 21,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/luciag-62901261',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 62901261,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': '¡¡NEGOCIABLE!! Sofá cheslong Nuevo, oportunidad!!',
#    'url': 'sofa-cheslong-perfecto-estado-336809348',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'citybump',
#    'categoryId': 12465,
#    'content': 'extensiones naturales entregas 24horas origen hindú cabello 100% natural humano se puede teñir,planchar,rizar,... todo como si fuera tu propio cabello trabajamos con la mejores extensiones y calidad para una sastifacion excelente para nuestras clientas. si no es el color que deseaba se lo cambiamos. largos desde 45 cm hasta 90 cm elije tus gramos desde 70g hasta 1kg de pelo. liso, ondulado y rizado. clip queratina adhesivas micro loop pelo suelto postizos coletas postizas flequillos californianas cortina hilo invisible.. envíos a toda españa, portugal, andorra, canarias, baleares, ceuta, melilla, francia, alemania, ee.uu... whatsapp; 631530804 bellasextensiones.es',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': 'Origen Hindú Cabello 100% natural humano se puede teñir,planchar,rizar,... todo como si fuera tu propio cabello trabajamos con la mejores extensiones y calidad para una sastifacion excelente para nuestras clientas. Si no es el color que deseaba se lo cambiamos. Largos desde 45 cm hasta 90 cm elije tus gramos desde 70g hasta 1kg de pelo. Liso, Ondulado y Rizado. clip queratina adhesivas micro loop pelo suelto postizos coletas postizas flequillos californianas cortina hilo invisible.. envíos a toda España, Portugal, Andorra, Canarias, Baleares, Ceuta, Melilla, Francia, Alemania, EE.UU... whatsapp; 631530804 bellasextensiones.es',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': 'b6becb',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W640',
#      'mobileScaledRatio': 133.33333730697632,
#      'originalHeight': 640,
#      'originalWitdh': 480,
#      'pictureId': 836753217,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 293,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 355513734,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': '8j3mn9kx5869',
#    'location': {'address': '',
#     'approximated_latitude': 40.41804346794747,
#     'approximated_location': True,
#     'approximated_longitude': -3.7010462636616595,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.030625369648843777,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4167754,
#     'longitude': -3.7037902,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': 'b6becb',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W640',
#     'mobileScaledRatio': 133.33333730697632,
#     'originalHeight': 640,
#     'originalWitdh': 480,
#     'pictureId': 836753217,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 293,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/5v/nw/__/c10420p355513734/i836753217.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '0 €',
#    'publishDate': 1556961595000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 0.0,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'xpzppx1e05z3',
#     'image': {'averageHexColor': 'b3a9ae',
#      'bigURL': 'https://cdn.wallapop.com/images/13/2p/ev/__/c13p163617298/i836102335.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/2p/ev/__/c13p163617298/i836102335.jpg?pictureSize=W640',
#      'mobileScaledRatio': 125.98425149917603,
#      'originalHeight': 960,
#      'originalWitdh': 762,
#      'pictureId': 836102335,
#      'smallURL': 'https://cdn.wallapop.com/images/13/2p/ev/__/c13p163617298/i836102335.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 277,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/2p/ev/__/c13p163617298/i836102335.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': '631530804 Extensiones100%Naturales ONLINE',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'maria-163617298',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '79 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 29,
#      'selledCount': 28,
#      'sellingCount': 79,
#      'sellsCount': 31,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/maria-163617298',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 163617298,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'Extensiones Naturales ENTREGAS 24HORAS',
#    'url': 'extensiones-naturales-entregas-24horas-355513734',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'countrybump',
#    'categoryId': 200,
#    'content': 'peñíscola apartamento 50mt playa superficie: 80 m2 nº de habitaciones: 2 nº de baños: 1 estado: buen estado precio especial mayo y junio se alquila por semanas, quincenas y meses. apartamento totalmente equipado. vitro nevera tv 42" microondas calentador electrico etc. ha 50 metros de las dos playas en la carrer de vilanova d´avinyó nº 6. con ascensor. situado en la mejor zona de peñiscola y en la mejor zona de playa. supermercado en la puerta de 1500m2. salón 2 habitaciones baño completo cocina. plaza de garaje. no se admiten mascotas se alquila los meses de mayo junio agosto septiembre octubre. codigo apartamento turistico vt37005cs del 1 al 25 de junio precio especial. tipo de inmueble: piso operación: alquiler garaje, ascensor',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': 'Superficie: 80 m2 Nº de habitaciones: 2 Nº de baños: 1 Estado: Buen estado PRECIO ESPECIAL MAYO Y JUNIO Se alquila por semanas, quincenas y meses. Apartamento totalmente equipado. Vitro nevera tv 42" microondas calentador electrico etc. Ha 50 metros de las dos playas en la Carrer de Vilanova d´Avinyó nº 6. Con ascensor. Situado en la mejor zona de Peñiscola y en la mejor zona de playa. Supermercado en la puerta de 1500m2. Salón 2 habitaciones baño completo cocina. Plaza de garaje. No se admiten mascotas Se alquila los meses de MAYO JUNIO AGOSTO SEPTIEMBRE OCTUBRE. CODIGO APARTAMENTO TURISTICO VT37005CS DEL 1 AL 25 DE JUNIO PRECIO ESPECIAL. Tipo de inmueble: Piso Operación: Alquiler Garaje, Ascensor',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': '686d81',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i523003478.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i523003478.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 3888,
#      'originalWitdh': 5184,
#      'pictureId': 523003478,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i523003478.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i523003478.jpg?pictureSize=W1024'},
#     {'averageHexColor': '6b6b6c',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511303385.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511303385.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 3888,
#      'originalWitdh': 5184,
#      'pictureId': 511303385,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511303385.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511303385.jpg?pictureSize=W1024'},
#     {'averageHexColor': '687585',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511298016.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/2b/x8/__/c10420p140959217/i511298016.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 3888,
#      'originalWitdh': 5184,
#      'pictureId': 511298016,
# ...
#     {'averageHexColor': '566670',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837584385.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837584385.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 756,
#      'originalWitdh': 1008,
#      'pictureId': 837584385,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837584385.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837584385.jpg?pictureSize=W1024'},
#     {'averageHexColor': '5a6167',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837588112.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837588112.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 756,
#      'originalWitdh': 1008,
#      'pictureId': 837588112,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837588112.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837588112.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 355778507,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': 'p61vr3k59d65',
#    'location': {'address': '',
#     'approximated_latitude': 40.41166817604409,
#     'approximated_location': True,
#     'approximated_longitude': -3.7024533579467325,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.6828999794621574,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.4115165,
#     'longitude': -3.7076445,
#     'neighborhood': None,
#     'postal_code': '28012',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': '7a90b7',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837582555.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837582555.jpg?pictureSize=W640',
#     'mobileScaledRatio': 127.11864709854126,
#     'originalHeight': 600,
#     'originalWitdh': 472,
#     'pictureId': 837582555,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837582555.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 279,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/5v/tk/__/c10420p355778507/i837582555.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '400 €',
#    'publishDate': 1557062985720,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 400.0,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'evjrlvdxo9jk',
#     'image': {'averageHexColor': '606c75',
#      'bigURL': 'https://cdn.wallapop.com/images/13/33/fe/__/c13p187155843/i830913002.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/33/fe/__/c13p187155843/i830913002.jpg?pictureSize=W640',
#      'mobileScaledRatio': 75.0,
#      'originalHeight': 3024,
#      'originalWitdh': 4032,
#      'pictureId': 830913002,
#      'smallURL': 'https://cdn.wallapop.com/images/13/33/fe/__/c13p187155843/i830913002.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 165,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/33/fe/__/c13p187155843/i830913002.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Lidia ..',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'mila-187155843',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '23 Productos',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 0,
#      'selledCount': 0,
#      'sellingCount': 23,
#      'sellsCount': 2,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/mila-187155843',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 187155843,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'marmol 40 kg',
#    'url': 'marmol-40-kg-355778507',
#    'viewsCounter': None},
#   {'activeItemPurchases': None,
#    'bumpType': 'countrybump',
#    'categoryId': 12579,
#    'content': 'cinta de correr technogym excite 500 oportunidad: se venden 1. 3 cintas de correr technogym excite 500. precio unidad: 1. 600€ 2.1 2 cintas de correr tochnogym xt pro 600. precio unidad: 750€ 2.2 4 cintas life fitness 95ti/tv precio unidad: 2000€. 3. 6 elipticas life fitness 93xi. precio unidad: 1800€ 4. 1 elíptica technogym sinchro excite 500. precio unidad: 1400€ 5. 1 elíptica life fitness 93xi. precio unidad: 1100€ 6. cross trainer technogym excite 500. precio unidad: 1800€ tenemos en stock amplia gama de equipamiento fitness de ocasión.todo en perfecto estado, con 6 meses de garantía. posibilidad de trasporte y instalación (no está incluido en el precio).',
#    'currency': {'currencyCode': 'EUR',
#     'defaultFractionDigits': 2,
#     'symbol': '€'},
#    'description': 'Oportunidad: se venden 1. 3 cintas de correr technogym excite 500. Precio unidad: 1. 600€ 2.1 2 cintas de correr tochnogym xt pro 600. Precio unidad: 750€ 2.2 4 cintas LIFE FITNESS 95ti/TV Precio unidad: 2000€. 3. 6 Elipticas life fitness 93xi. Precio unidad: 1800€ 4. 1 elíptica technogym sinchro excite 500. Precio unidad: 1400€ 5. 1 elíptica life fitness 93xi. Precio unidad: 1100€ 6. cross trainer technogym excite 500. Precio unidad: 1800€ Tenemos en stock amplia gama de equipamiento fitness de ocasión.Todo en perfecto estado, con 6 meses de garantía. Posibilidad de trasporte y instalación (no está incluido en el precio).',
#    'expired': False,
#    'favorite': None,
#    'favouriteCounter': None,
#    'imageCount': None,
#    'images': [{'averageHexColor': '62707b',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W640',
#      'mobileScaledRatio': 133.33333730697632,
#      'originalHeight': 1600,
#      'originalWitdh': 1200,
#      'pictureId': 808355990,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 293,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W1024'},
#     {'averageHexColor': '6f7277',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375229.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375229.jpg?pictureSize=W640',
#      'mobileScaledRatio': 158.20399522781372,
#      'originalHeight': 1427,
#      'originalWitdh': 902,
#      'pictureId': 808375229,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375229.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 348,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375229.jpg?pictureSize=W1024'},
#     {'averageHexColor': '7a7778',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808386611.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808386611.jpg?pictureSize=W640',
#      'mobileScaledRatio': 177.77777910232544,
#      'originalHeight': 1600,
#      'originalWitdh': 900,
#      'pictureId': 808386611,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808386611.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 391,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808386611.jpg?pictureSize=W1024'},
#     {'averageHexColor': '5d6d7c',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808371287.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808371287.jpg?pictureSize=W640',
#      'mobileScaledRatio': 133.33333730697632,
#      'originalHeight': 1024,
#      'originalWitdh': 768,
#      'pictureId': 808371287,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808371287.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 293,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808371287.jpg?pictureSize=W1024'},
#     {'averageHexColor': '606f7c',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808390310.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808390310.jpg?pictureSize=W640',
#      'mobileScaledRatio': 133.33333730697632,
#      'originalHeight': 1600,
#      'originalWitdh': 1200,
#      'pictureId': 808390310,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808390310.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 293,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808390310.jpg?pictureSize=W1024'},
#     {'averageHexColor': '7e7d7f',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375236.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375236.jpg?pictureSize=W640',
#      'mobileScaledRatio': 177.77777910232544,
#      'originalHeight': 1600,
#      'originalWitdh': 900,
#      'pictureId': 808375236,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375236.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 391,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808375236.jpg?pictureSize=W1024'},
#     {'averageHexColor': '757473',
#      'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808392284.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808392284.jpg?pictureSize=W640',
#      'mobileScaledRatio': 177.77777910232544,
#      'originalHeight': 1600,
#      'originalWitdh': 900,
#      'pictureId': 808392284,
#      'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808392284.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 391,
#      'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808392284.jpg?pictureSize=W1024'}],
#    'itemBumpFlags': {'bumped': True, 'urgent': False},
#    'itemCar': None,
#    'itemCounters': None,
#    'itemExtraInfoDto': None,
#    'itemId': 346736627,
#    'itemRealEstate': None,
#    'itemSaleConditions': None,
#    'itemUUID': 'nz0ge1m4rdjo',
#    'location': {'address': '',
#     'approximated_latitude': 40.41297432685359,
#     'approximated_location': True,
#     'approximated_longitude': -3.7104138616875857,
#     'city': 'Madrid',
#     'cityLink': None,
#     'cityLinkTitle': None,
#     'country_code': 'ES',
#     'distance_from_you': 0.39435649743641576,
#     'district': None,
#     'fullAddress': None,
#     'latitude': 40.42028,
#     'longitude': -3.70578,
#     'neighborhood': None,
#     'postal_code': '28001',
#     'region': 'Comunidad de Madrid',
#     'region2': 'Madrid'},
#    'mainImage': {'averageHexColor': '62707b',
#     'bigURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W800',
#     'imageId': 0,
#     'mediumURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W640',
#     'mobileScaledRatio': 133.33333730697632,
#     'originalHeight': 1600,
#     'originalWitdh': 1200,
#     'pictureId': 808355990,
#     'smallURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W320',
#     'type': 'jpg',
#     'webScaledHeight': 293,
#     'xlargeURL': 'https://cdn.wallapop.com/images/10420/5q/fr/__/c10420p346736627/i808355990.jpg?pictureSize=W1024'},
#    'mapLink': None,
#    'mine': False,
#    'onHold': False,
#    'pendingReview': False,
#    'pendingUpload': False,
#    'price': '1.600 €',
#    'publishDate': 1554736264000,
#    'publishDateStr': None,
#    'realState': False,
#    'reserved': False,
#    'salePrice': 1600.0,
#    'sellerUser': {'banned': False,
#     'carDealerExtraInfoAPI': None,
#     'coverImage': None,
#     'email': None,
#     'favorite': False,
#     'featuredProfile': False,
#     'formattedRegistrationDate': None,
#     'hashId': 'dqjwx3r7xe6o',
#     'image': {'averageHexColor': '8694a5',
#      'bigURL': 'https://cdn.wallapop.com/images/13/30/3n/__/c13p181569553/i808462831.jpg?pictureSize=W800',
#      'imageId': 0,
#      'mediumURL': 'https://cdn.wallapop.com/images/13/30/3n/__/c13p181569553/i808462831.jpg?pictureSize=W640',
#      'mobileScaledRatio': 83.88429880142212,
#      'originalHeight': 203,
#      'originalWitdh': 242,
#      'pictureId': 808462831,
#      'smallURL': 'https://cdn.wallapop.com/images/13/30/3n/__/c13p181569553/i808462831.jpg?pictureSize=W320',
#      'type': 'jpg',
#      'webScaledHeight': 184,
#      'xlargeURL': 'https://cdn.wallapop.com/images/13/30/3n/__/c13p181569553/i808462831.jpg?pictureSize=W1024'},
#     'location': None,
#     'microName': 'Valentina G.',
#     'paymentDetails': None,
#     'professional': False,
#     'publishedItems': [],
#     'registrationDate': None,
#     'screenName': 'valentinag-181569553',
#     'statsUser': {'buysCount': 0,
#      'conversationReadPendingCount': 0,
#      'favoritesCount': 0,
#      'notificationReadPendingCount': 0,
#      'prodsFavoritesCount': None,
#      'prodsSelledCount': None,
#      'prodsSellingCount': '1 Producto',
#      'purchasedCount': 0,
#      'receivedReviewsCount': 0,
#      'selledCount': 0,
#      'sellingCount': 1,
#      'sellsCount': 0,
#      'sendReviewsCount': 0,
#      'shippingCount': 0,
#      'userReceivedReviewsCount': None},
#     'url': '/user/valentinag-181569553',
#     'userBumpedExtraInfo': None,
#     'userExtraInfo': None,
#     'userId': 181569553,
#     'validation': None},
#    'sold': False,
#    'soldDate': None,
#    'title': 'CINTA DE CORRER TECHNOGYM EXCITE 500',
#    'url': 'cinta-de-correr-technogym-excite-500-346736627',
#    'viewsCounter': None}],
#  'keywords': None,
#  'lastItemId': None,
#  'latitude': 40.4167635,
#  'longitude': -3.7038088,
#  'nextPage': 0,
#  'noResultsDescription': None,
#  'noResultsImg': None,
#  'noResultsTitle': None,
#  'numPage': 0,
#  'pageHOne': 'Segunda mano',
#  'pageMetaDescription': 'Productos de segunda mano. Encuentra lo que estás buscando cerca de ti en Wallapop. Compra y vende entre particulares y profesionales',
#  'pageTitle': 'Segunda mano en WALLAPOP',
#  'prevPage': 0,
#  'previousItemId': None,
#  'searchId': 'e305a460-1b02-438f-9c9c-eb7908b47d4d',
#  'searchNextPage': 'start=80&step=0&bumpCollectionType=0&densityType=20&itemsCount=40&search_id=e305a460-1b02-438f-9c9c-eb7908b47d4d&orderType=asc&latitude=40.4167635&orderBy=distance&distanceSegments=_400000&longitude=-3.7038088',
#  'total': -1}

# %% [markdown]
# ## Análisis de datos

# %%
df_wallapop = pd.DataFrame(data)
df_wallapop['items'][0].keys()
# Out:
# dict_keys(['itemId', 'itemUUID', 'title', 'description', 'categoryId', 'mainImage', 'images', 'imageCount', 'salePrice', 'currency', 'price', 'sellerUser', 'url', 'itemCounters', 'favouriteCounter', 'viewsCounter', 'sold', 'soldDate', 'reserved', 'itemCar', 'publishDate', 'publishDateStr', 'itemSaleConditions', 'favorite', 'mapLink', 'itemBumpFlags', 'mine', 'bumpType', 'itemRealEstate', 'location', 'activeItemPurchases', 'itemExtraInfoDto', 'pendingReview', 'pendingUpload', 'onHold', 'expired', 'realState', 'content'])

# %%
titulos = pd.Series([x['title'] for x in df_wallapop['items']]).rename('titulos')
precios = pd.Series([x['salePrice'] for x in df_wallapop['items']]).rename('precios')
des_precios = pd.concat([titulos, precios], axis=1)
des_precios
# Out:
#                                               titulos  precios
# 0            CANAPE ABATIBLE TAPIZADO 3D MADERA NUEVO    139.0
# 1          CANAPE ABATIBLE + COLCHON + ALMOHADA NUEVO    225.0
# 2                         Pack canape + colchon NUEVO    215.0
# 3                                                Sofá    399.0
# 4   ¡¡NEGOCIABLE!! Sofá cheslong Nuevo, oportunidad!!    690.0
# 5              Extensiones Naturales ENTREGAS 24HORAS      0.0
# 6                    PEÑÍSCOLA APARTAMENTO 50MT PLAYA    350.0
# 7                                   Canon 5d mark iii   1400.0
# 8   ENVIO GRATIS US Apple Cargador Original Precin...     10.0
# 9                 VW076368 Audi TT 1.8T Roadster 2003   4700.0
# 10                HW002823 Porsche Cayenne Basis 2006  11700.0
# 11     SA75169 BMW 3er 320d EfficientDynamics Touring   8900.0
# 12                         UP031000 Suzuki Jimny 2009   8900.0
# 13                   UB097089 Peugeot 207 1.4 XS 2006   2500.0
# 14      HZ059787 Volkswagen Passat 1.8 Trendline 2000   1390.0
# 15   RP031993 Volkswagen Golf V 1.9 TDI Highline 2004   3800.0
# 16   SP016798 Mitsubishi Montero IO 1.8 GDI Plus 1999   3600.0
# 17                       TU114844 Renault Megane 2006   4500.0
# 18                         Mesas de oficina desde 89€     89.0
# 19              Nikon D3300 + Objetivo Nikon 18-55 MM    310.0
# 20                                    pequeños portes     20.0
# 21  Lavadora Indesit 9 K 1400 Rpm A+++ GARANTIA Llevo    199.0
# 22                        VENTA MAQUINARIA HOSTELERIA      1.0
# 23      Lavadora Aeg 8 K 1200 Rpm A+++ GARANTIA Llevo    179.0
# 24  Lavadora Aeg 8 K 1200 Rpm A+ GARANTIA Llevo a ...    149.0
# 25     Lavadora Bosch 7 K 1200 Rpm A+A GARANTIA Llevo    129.0
# 26  LAVADORA 6 K. 100€ TRANSPORTE-INSTALACION INCL...    100.0
# 27      Lavadora C. Superior Indesit 5 K 1000 Rpm A++    119.0
# 28     Lavadora Balay 7 K 1000 Rpm A+A GARANTIA Llevo    109.0
# 29    Lavadora Siemens 6 K 1100 Rpm A+ GARANTIA Llevo     99.0
# 30  Curso crear APPS SIN programar y GENERAR ingre...     35.0
# 31      Somier de lamas con colchón nuevo y almohada.     80.0
# 32                                 Cartel Caja de Luz    270.0
# 33                  Smartwatch Huawei Wacht GT Active    200.0
# 34                                   Toyota RAV4 2017  27500.0
# 35               Portes y mudanzas.Seriedad y rapidez     11.0
# 36                   Bata Ideal seda y encaje años 70     15.0
# 37  e-scooter,patinete eléctrico,eco-movilidad,#t....    775.0
# 38                                       marmol 40 kg    400.0
# 39               CINTA DE CORRER TECHNOGYM EXCITE 500   1600.0

# %%
# %matplotlib inline
des_precios['precios'].plot.box()

# %%
des_precios[des_precios['precios'] < 50].plot.box()

# %%
des_precios[des_precios['precios'] < 50]
# Out:
#                                               titulos  precios
# 5              Extensiones Naturales ENTREGAS 24HORAS      0.0
# 8   ENVIO GRATIS US Apple Cargador Original Precin...     10.0
# 20                                    pequeños portes     20.0
# 22                        VENTA MAQUINARIA HOSTELERIA      1.0
# 30  Curso crear APPS SIN programar y GENERAR ingre...     35.0
# 35               Portes y mudanzas.Seriedad y rapidez     11.0
# 36                   Bata Ideal seda y encaje años 70     15.0

# %%
import qgrid
qgrid_widget = qgrid.show_grid(df_wallapop, show_toolbar=True)
qgrid_widget

# %% [markdown]
# ## Procesamiento del lenguaje natural
#
#
# - [Ejemplos simples con antónimos](https://likegeeks.com/es/tutorial-de-nlp-con-python-nltk/)

# %%
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')

mytext = "Hello Adam, how are you? I hope everything is going well. Today is a good day, see you dude."
 
print(sent_tokenize(mytext))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Hello Adam, how are you?', 'I hope everything is going well.', 'Today is a good day, see you dude.']

# %%
from nltk.corpus import wordnet
nltk.download('wordnet')

synonyms = []
 
for syn in wordnet.synsets('computer'):
 
    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system', 'calculator', 'reckoner', 'figurer', 'estimator', 'computer']

# %% [markdown]
# ## Inteligencia artificial
#
# ... cuando lo entienda te lo cuento. De momento:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mJeNghZXtMo', width=800, height=300)

# %% [markdown]
# ### Ejemplos con música
#
# * [Machine Learning haciendo música](https://colab.research.google.com/drive/1s6W7iINjj3MAfVWc3wpVlPyGq8TuzWH9)

# %% [markdown]
# ## Automatización tareas
#
# - [Libro automatiza](https://automatetheboringstuff.com/)

# %%
import pyautogui
screenWidth, screenHeight = pyautogui.size()
currentMouseX, currentMouseY = pyautogui.position()
pyautogui.moveTo(100, 150)
pyautogui.click()
# pyautogui.moveRel(None, 10)  # move mouse 10 pixels down
# pyautogui.doubleClick()
# pyautogui.moveTo(500, 500, duration=2, tween=pyautogui.easeInOutQuad)  # use tweening/easing function to move mouse over 2 seconds.
# pyautogui.typewrite('Hello world!', interval=0.25)  # type with quarter-second pause in between each key
# pyautogui.press('esc')
# pyautogui.keyDown('shift')
# pyautogui.press(['left', 'left', 'left', 'left', 'left', 'left'])
# pyautogui.keyUp('shift')
# pyautogui.hotkey('ctrl', 'c')

# %% [markdown]
# ## Desarrollo de aplicaciones
#
# - Web: [Django](https://www.djangoproject.com/). Muy interesante [Wagtail](https://wagtail.io/) y [Coderedcms](https://docs.coderedcorp.com/cms/stable/getting_started/install.html)
# - De escritorio: [Tkinter](https://likegeeks.com/es/ejemplos-de-la-gui-de-python/) o [Gooey](https://pypi.org/project/Gooey/)
#
# ```python
# # EXAMPLE OF CODEREDCMS
# # in a Python 3 virtual environment
# pip install coderedcms
# coderedcms start mysite
# cd mysite
# python manage.py migrate
# python manage.py createsuperuser
# python manage.py runserver
# ```

# %% [markdown]
# ## Aplicación en otros campos
#
# * [Ciencias sociales: recreación de la visualización del Gapminder dataset](https://colab.research.google.com/drive/1MucxxfaLjmqnjYg4-qy8C8piVFzw757I)

# %% [markdown]
# ## Internet of Things
#
# - Python y microbit. [Web](https://python.microbit.org/v/1.1) y [documentación](https://microbit-micropython.readthedocs.io/en/v1.0.1/tutorials/introduction.html). Sólo uno de los muchos ejemplos.

# %% [markdown]
# # Enlaces de interés
#
# * [Para testear expresiones regulares](https://regex101.com/)
# * [Tutorial interesante de Web-Scraping](https://www.dataquest.io/blog/web-scraping-beautifulsoup/)
#
# ## Podcasts
#
# * [Python Bytes](https://pythonbytes.fm/)
# * [Talk Python to me](https://talkpython.fm/)
# * [Programar es una mierda](https://www.ivoox.com/podcast-programar-es-mierda_sq_f1432444_1.html)
#
# ## Plataformas de aprendizaje online
#
# * [Edx](https://www.edx.org/es)
# * [Coursera](https://www.coursera.org/)
# * [Miriadax](https://miriadax.net/home)
# * [DataCamp](https://www.datacamp.com/)
# * [Dataquests.io](https://www.dataquest.io/)
# * [Khanacademy](https://es.khanacademy.org/)
# * [Scoth.io](https://scotch.io/)
# * [PluralSight](https://www.pluralsight.com/)
# * [Egghead.io](https://egghead.io/)
# * [Code.org](https://code.org/)
# * [Kaggle](https://www.kaggle.com/)
# * [codeacademy](https://www.codecademy.com/es)
# * [Codepen para aprender desarrollo web](https://codepen.io/)
# * [Freecodecamp](https://www.freecodecamp.org/)
# * [Microsoft Virtual Academy](https://mva.microsoft.com/)
# * [Learnenough.com](https://www.learnenough.com/)
#
# ## Cursos interesantes
#
# * [Aprendiendo a aprender](https://es.coursera.org/learn/aprendiendo-a-aprender)
# * [cs50 de Harvard](https://www.edx.org/es/course/cs50s-introduction-computer-science-harvardx-cs50x)
# * [Python for Everybody](https://es.coursera.org/specializations/python)
# * [Introducción a Python](https://www.datacamp.com/courses/intro-to-python-for-data-science)
# * [Intro a Python en CodeAcademy](https://www.codecademy.com/learn/learn-python)
#
# ## Herramientas útiles
#
# * [Diigo](https://www.diigo.com/)
# * [Pocket](https://getpocket.com/)
# * [Medium](https://medium.com/)
# * [Anki](https://apps.ankiweb.net/)
# * [Feedly](https://feedly.com/)
# * [TTS](https://www.texttomp3.online/) Hay muchas, esta es sólo un ejemplo.
#
# ## Librerías
#
# * [Bokeh](https://bokeh.pydata.org/en/latest/)
# * [Jupyter](https://bokeh.pydata.org/en/latest/)
# * [Numpy](http://www.numpy.org/)
# * [Pandas](https://pandas.pydata.org/)

# %% [markdown]
# ## ¿Cómo busco librerías de interés?
#
# Github es actualmente la mayor comunidad de código abierto. Son muy interesantes las listas 'awesome'. Escribe `awesome <lo que sea> github` en google y verás.

# %% [markdown]
# # Repasamos lo aprendido
#
# - [Kahoot!](https://kahoot.it)
